# %%
# import pandas library
import pandas as pd

# %%
#read the csv file
df = pd.read_csv(r"./case_info.csv")

# %%
# head function  will show minimum five column
df.head()
# Out:
#              State/UTs  Total Vaccination Doses    Dose 1    Dose 2  \
# 0  Andaman and Nicobar                   629054    311893    317161
# 1       Andhra Pradesh                 84147957  40624263  43523694
# 2    Arunachal Pradesh                  1596166    856732    739434
# 3                Assam                 42998698  22535419  20463279
# 4                Bihar                119963226  62590002  57373224
#
#    Population  NoDoseOnePopulation  NoDoseTwoPopulation
# 0      399001                87108                81840
# 1    91702478             51078215             48178784
# 2     1711947               855215               972513
# 3    35998752             13463333             15535473
# 4   128500364             65910362             71127140

# %%
df.shape
# Out:
# (36, 7)

# %%
#Looking for summary
df.columns
# Out:
# Index(['State/UTs', 'Total Vaccination Doses', 'Dose 1', 'Dose 2',
#        'Population', 'NoDoseOnePopulation', 'NoDoseTwoPopulation'],
#       dtype='object')

# %%
# Checking missing values
df.isnull().sum()
# Out:
# State/UTs                  0
# Total Vaccination Doses    0
# Dose 1                     0
# Dose 2                     0
# Population                 0
# NoDoseOnePopulation        0
# NoDoseTwoPopulation        0
# dtype: int64

# %%
# describe() is used to view some basic statistical details like count, mean, std, for  given csv file
df.describe()
# Out:
#        Total Vaccination Doses        Dose 1        Dose 2    Population  \
# count             3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01
# mean              4.921979e+07  2.549133e+07  2.372846e+07  3.971861e+07
# std               6.252012e+07  3.226311e+07  3.029808e+07  5.050913e+07
# min               1.123780e+05  5.683100e+04  5.554700e+04  6.600100e+04
# 25%               1.906027e+06  1.042061e+06  8.696295e+05  1.695473e+06
# 50%               3.381891e+07  1.770508e+07  1.495231e+07  2.410088e+07
# 75%               8.740200e+07  4.278546e+07  4.417638e+07  6.979986e+07
# max               2.997738e+08  1.536694e+08  1.461044e+08  2.315026e+08
#
#        NoDoseOnePopulation  NoDoseTwoPopulation
# count         3.600000e+01         3.600000e+01
# mean          1.422728e+07         1.599015e+07
# std           1.936199e+07         2.119403e+07
# min           9.170000e+03         1.045400e+04
# 25%           8.269272e+05         9.617025e+05
# ...

# %%
# draw scatter plot between Population over dose1
df.plot(kind='scatter',x='Population', y='Dose 1' , alpha=0)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Dose 1'>

# %%
df.min()
# Out:
# State/UTs                  Andaman and Nicobar
# Total Vaccination Doses                 112378
# Dose 1                                   56831
# Dose 2                                   55547
# Population                               66001
# NoDoseOnePopulation                       9170
# NoDoseTwoPopulation                      10454
# dtype: object

# %% [markdown]
# ---------

# %% [markdown]
# DEVELOPMENT.
#
# **Analysis**

# %%
# dose 1 - Not vaccinated
NoDoseOnepopulation = df["Population"] - df["Dose 1"]
df = df.assign(NoDoseOnePopulation=NoDoseOnepopulation)
df
# Out:
#                                    State/UTs  Total Vaccination Doses  \
# 0                        Andaman and Nicobar                   629054
# 1                             Andhra Pradesh                 84147957
# 2                          Arunachal Pradesh                  1596166
# 3                                      Assam                 42998698
# 4                                      Bihar                119963226
# 5                                 Chandigarh                  2001114
# 6                               Chhattisgarh                 36927545
# 7   Dadra and Nagar Haveli and Daman and Diu                  1319914
# 8                                      Delhi                 30710281
# 9                                        Goa                  2572559
# 10                                   Gujarat                 98534412
# 11                                   Haryana                 40581317
# ...

# %%
#dose 2 - Not vaccinated
NoDoseTwoPopulation = df["Population"] - df["Dose 2"]
df = df.assign(NoDoseTwoPopulation=NoDoseTwoPopulation)
df
# Out:
#                                    State/UTs  Total Vaccination Doses  \
# 0                        Andaman and Nicobar                   629054
# 1                             Andhra Pradesh                 84147957
# 2                          Arunachal Pradesh                  1596166
# 3                                      Assam                 42998698
# 4                                      Bihar                119963226
# 5                                 Chandigarh                  2001114
# 6                               Chhattisgarh                 36927545
# 7   Dadra and Nagar Haveli and Daman and Diu                  1319914
# 8                                      Delhi                 30710281
# 9                                        Goa                  2572559
# 10                                   Gujarat                 98534412
# 11                                   Haryana                 40581317
# ...

# %% [markdown]
# #VISUALIZATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"./case_info.csv")
plt.figure(figsize=(12, 6))
sns.barplot(data=data)
plt.xticks(rotation=90)
plt.title('Total Vaccination Doses by State/UTs')
plt.show()
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #FEATURE ENGINEERING - EXPLORATARY DATA ANALYSIS(EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas DataFrame with the provided data
data = pd.DataFrame({
    'State/UTs': ['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa'],
    'Total Vaccination Doses': [629054, 84147957, 1596166, 42998698, 119963226, 2001114, 36927545, 1319914, 30710281, 2572559],
    'Dose 1': [311893, 40624263, 856732, 22535419, 62590002, 1088086, 18855121, 729023, 16555043, 1353009],
    'Dose 2': [317161, 43523694, 739434, 20463279, 57373224, 913028, 18072424, 590891, 14155238, 1219550],
    'Population': [399001, 91702478, 1711947, 35998752, 128500364, 1158040, 32199722, 773997, 19301096, 1521992]
})

# Display the first few rows of the dataset
print(data.head())

# Calculate basic statistics
summary_statistics = data.describe()
print(summary_statistics)

# Create a bar plot to visualize Total Vaccination Doses by State/UTs
plt.figure(figsize=(10, 6))
plt.bar(data['State/UTs'], data['Total Vaccination Doses'])
plt.title('Total Vaccination Doses by State/UTs')
plt.xlabel('State/UTs')
plt.ylabel('Total Vaccination Doses')
plt.xticks(rotation=45)
plt.show()

# Create a scatter plot to visualize the relationship between Dose 1 and Dose 2
plt.figure(figsize=(10, 6))
plt.scatter(data['Dose 1'], data['Dose 2'], alpha=0.5)
plt.title('Dose 1 vs. Dose 2')
plt.xlabel('Dose 1')
plt.ylabel('Dose 2')
plt.grid(True)
plt.show()
# Out:
#              State/UTs  Total Vaccination Doses    Dose 1    Dose 2  \
# 0  Andaman and Nicobar                   629054    311893    317161
# 1       Andhra Pradesh                 84147957  40624263  43523694
# 2    Arunachal Pradesh                  1596166    856732    739434
# 3                Assam                 42998698  22535419  20463279
# 4                Bihar                119963226  62590002  57373224
#
#    Population
# 0      399001
# 1    91702478
# 2     1711947
# 3    35998752
# 4   128500364
#        Total Vaccination Doses        Dose 1        Dose 2    Population
# count             1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# mean              3.228665e+07  1.654986e+07  1.573679e+07  3.132674e+07
# std               4.112141e+07  2.100441e+07  2.016206e+07  4.449801e+07
# min               6.290540e+05  3.118930e+05  3.171610e+05  3.990010e+05
# 25%               1.697403e+06  9.145705e+05  7.828325e+05  1.249028e+06
# ...
